# %% [markdown]
# Objective: create a daily news summarizer app

# %%
Runs everyday for a given topic

# %% [markdown]
# Takes last 24 hours to search for news
# Summarizes the news and sends it to me

# %%
a=1

# %%
b=a+3
